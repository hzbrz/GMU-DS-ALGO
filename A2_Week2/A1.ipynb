# %% [markdown]
# # IT-309 - Homework #1 Template - Algorithm analysis
#
# ## Name: <type your name here>
#
# Note: to change or overwrite a Markdown cell first change its type to 'Code', type changes in the cell, change the cell back to 'Markdown', then 'Run'.

# %% [markdown]
# ### The homework problems are presented in cells below.  Provide written answers in Markdown cells when "pencil/paper" answers are expected.  Provide coded cells with Python code if/when that is expected.

# %% [markdown]
# ### This assignment is worth 40 points.  The weighting rubric for the 6 problems is as follows:
# Problem 1:     3 points
# Problem 2:     2 points
# Problem 3, Q1: 1 point
# Problem 3: Q2: 3 points
# Problem 3: Q3: 3 points
# Problem 4: Q1: 3 points
# Problem 4: Q2: 3 points
# Problem 4: Q3: 3 points
# Problem 4: Q4: 3 points
# Problem 5: Q1: 4 points
# Problem 5: Q2: 1 point
# Problem 6: Q1: 4 points
# Problem 6: Q2: 1 point
# Problem 6: Q3: 2 points
# Problem 6: Q4: 2 points
# Problem 6: Q5: 2 points
#
# #### Total         40 points

# %% [markdown]
# ==============================================================================================================
# ### Problem 1:  For the time analysis (T(n)) functions in the table below provide the big-Oh for each in the cell that follows.  Use the associated number in the left column to refer to the function.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### To type the answers, click on this cell, convert it to type 'Code', type in the answers where you want them, convert the cell back to 'Markdown', then 'Run'.
#
# No. 1:  O(n$^2$)
#
# No. 2:  O(n log n)
#
# No. 3:  O(n)
#
# No. 4:  O(2$^n$)
#
# No. 5:  O(1)
#
# No. 6:  O(n$^3$)
#
# No. 7:  O(log n)

# %% [markdown]
# ==========================================================================================================
# ### Problem 2: For the seven functions in the table write them in order of growth as a function of input.  List the slowest growth rate first, then the next fastest, and so on.  The fastest growth rate (generally the slowest running algorithm) will be last.  Use the numbers from the table.  Put the answer in the next cell as a series of numbers, 1 to 7, separated by commas.

# %% [markdown]
# #### Functions in order of growth rate (slowest to fastest):
#
# Answer: 5, 7, 3, 2, 1, 6, 4

# %% [markdown]
# =======================================================================================================
# ### Problem 3:  Using matplotlib to create a graph
#
# #### Look at the code in the next two cells.  It imports matplotlib and numpy in the first, then generates a plot of four different functions in the second.  The scale of the plot is specified on the first line as 0 to 10 with 100 random points generated. The scale can be adjusted above 10 for a wider/larger scale, or less than 10 for a smaller scale.
# #### Run the code in both cells to view the graph.  Then follow the instructions in subsequent cells. If you have trouble importing the libraries or cannot otherwise run the code to generate the graphs, open the HW#1 Emergency notebook to view them.  Then return to this one to answer the questions below.

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Code to generate a graph of various functions using matplotlib and numpy

n = np.linspace(0, 10, 100) # generate 100 sample points in range 1 to 10 - change the 10 to a different scale
# Generate lines on the graph
plt.plot(n, 8*n, label = '8n: linear')                  # graph a linear function
plt.plot(n, 2*n**2, label = '2n**2: quadratic')         # graph a quadratic function  
plt.plot(n, n**3, label = 'n**3: cubic')                # graph a cubic function
plt.plot(n, 2**n, label = '2**n: exponential')          # graph an exponential function 
# Labels
plt.title('textrbook: R3.1 - comparison plot of various growth functions')
plt.legend()
# Do it!
plt.show()

# %% [markdown]
# #### P3, Q1: In the cell below copy and paste the graphing code from above, change the scale to 12, then rerun.  What differences do you see in the generated functions compared with the first one whose scale only went to 10?
#
# > <b>Answer</b>: By changing the scale, the difference between cubic and exponential as well as the other functions are more pronounced. In the last graph it was harder to tell if cubic function was slower than the exponential but in this scale it is easy to see that the exponential is the worst of all the functions

# %%
n = np.linspace(0, 12, 100) # generate 100 sample points in range 1 to 10 - change the 10 to a different scale
# Generate lines on the graph
plt.plot(n, 8*n, label = '8n: linear')                  # graph a linear function
plt.plot(n, 2*n**2, label = '2n**2: quadratic')         # graph a quadratic function  
plt.plot(n, n**3, label = 'n**3: cubic')                # graph a cubic function
plt.plot(n, 2**n, label = '2**n: exponential')          # graph an exponential function 
# Labels
plt.title('textrbook: R3.1 - comparison plot of various growth functions')
plt.legend()
# Do it!
plt.show()

# %% [markdown]
# #### P3, Q2: In the cell below copy and paste the graphing code, change the scale to 20, then rerun.  What differences do you see in the generated functions compared with the first two above?
#
# > <b>Answer</b>: All functions have flattened expect for the exponential function showing that the exponential function grows at a massive rate (compared to the other fucntions) after a certain amount of inputs.

# %%
n = np.linspace(0, 20, 100) # generate 100 sample points in range 1 to 10 - change the 10 to a different scale
# Generate lines on the graph
plt.plot(n, 8*n, label = '8n: linear')                  # graph a linear function
plt.plot(n, 2*n**2, label = '2n**2: quadratic')         # graph a quadratic function  
plt.plot(n, n**3, label = 'n**3: cubic')                # graph a cubic function
plt.plot(n, 2**n, label = '2**n: exponential')          # graph an exponential function 
# Labels
plt.title('textrbook: R3.1 - comparison plot of various growth functions')
plt.legend()
# Do it!
plt.show()

# %% [markdown]
# #### P3, Q3: In the cell below copy and paste the graphing code, change the scale to 3, then rerun.  What differences do you see in the generated functions compared with the ones above?
#
# > <b>Answer</b>: With a small scale the graph gives the wrong sense that the eponential function is the best performing when this is not the case. However we do see the linearity for the linear function but can see an upward growth for the other functions.

# %%
n = np.linspace(0, 3, 100) # generate 100 sample points in range 1 to 10 - change the 10 to a different scale
# Generate lines on the graph
plt.plot(n, 8*n, label = '8n: linear')                  # graph a linear function
plt.plot(n, 2*n**2, label = '2n**2: quadratic')         # graph a quadratic function  
plt.plot(n, n**3, label = 'n**3: cubic')                # graph a cubic function
plt.plot(n, 2**n, label = '2**n: exponential')          # graph an exponential function 
# Labels
plt.title('textrbook: R3.1 - comparison plot of various growth functions')
plt.legend()
# Do it!
plt.show()

# %% [markdown]
# ============================================================================================================
# ### Problem 4: We can use the functions we've studied to predict how an algorithm's time performance might scale up for larger inputs if we know actual timings for a run with a small input set.
#
# ### For example, for an O(n^2) algorithm ("Oh n-squared"):
#
# If T(n) = .01 seconds for 100 inputs, how long will it take the algorithm to process 10,000 inputs?
#
# >To solve, use a ratio equation:
#
# >.01 / (100^2)  =  n / (10000^2) ...    # we square the 100 and 10000 because the algorithm has O(n^2) growth
#
# >n = (.01 x 10000^2) / (100^2)
#
# >n = 100 seconds  to process 10,000 inputs

# %%
# Run this cell to see how you can use the Python interpreter to calculate an expression like the one above:
n = (.01*10000**2)/100**2
print('Answer is: ', n, ' seconds')
# Out:
# Answer is:  100.0  seconds

# %% [markdown]
# #### P4, Q1: In the cell (or cells - you can do calculations directly in cells if you want) below determine how long it would take an O(n^3) algorithm to process 1,000 inputs if we know that processing 10 inputs takes .001 seconds.  If you calculate in a cell be sure it clearly shows the answer.  Alternately, show the calculation in one cell and the answer in a different Markdown cell.  Use the above code as a template if you want to use Python to do the calculation.

# %%
n = (.001*1000**3)/10**3
print(n)
# Out:
# 1000.0

# %% [markdown]
# >n = 1000 seconds or 16.6 minutes to process 1000 inputs

# %% [markdown]
# #### P4, Q2: In the cell (or cells) below determine how long it would take an O(2^n) algorithm (2 to the nth power - exponential) to process 40 inputs if we know that processing 10 inputs takes .0001 seconds. If the answer is large, how many minutes, hours, days, etc. might this require?

# %%
n = (.0001*2**40)/2**10
print(n)
# Out:
# 107374.1824

# %% [markdown]
# >n = 107374.1824 seconds or 1789.57 minutes or 29.83 hours or 1.24 days to process 40 inputs

# %% [markdown]
# #### P4, Q3: In the cell (or cells) below determine how long it would take an O(n lg n) algorithm to process 100,000 inputs if we know that processing 10 inputs takes .0001 seconds. Since we're dealing with estimates you may assume "lg 10" is 3.15 and "lg 100,000" is 16.6.

# %%
n = (.0001*100000*16.6)/10**3.15
print(n)
# Out:
# 0.11751900020776691

# %% [markdown]
# >n = 0.118 seconds to process 100000 inputs

# %% [markdown]
# #### P4, Q4: What difference do you see in the speed with which the above algorithms would be expected to scale up to larger input sizes?  Each seems to do well at low volumes.  How well at higher volumes?

# %% [markdown]
# > <b>Answer</b>: Out of all 3 functions above n log n function seems to work the best. The cubic function does well upto 100 inputs but quickly becomes worse for anything above that. The exponential function has the worst time performance.

# %% [markdown]
# ===========================================================================================================
# ### Problem 5: View the code in the cell below, then answer the questions in the cells that follow.

# %%
def example1(S):     # from textbook, section 3.5, page 143
    """ Return the sum of the elements in sequence S. """
    n = len(S)
    total = 0
    for j in range (n):
        total += S[j]
    return total

# %% [markdown]
# #### P5, Q1: What is the T(n) for the above code based on a static analysis?  You may use the symbol 'c' for anything that's constant rather than trying to estimate the number of operations.  For example, T(n) = c*n^2 + c*n + c  is a valid function (n^2 is "n-squared").  We can do that because our analysis showed that the constant factors are not crucial when measuring the growth rate.  Then, the big-Oh family of this particular function, T(n), is O(n^2) based on the cn^2 factor.
#
# Put your response in the next cell.

# %% [markdown]
# > c + c(n)

# %% [markdown]
# #### P5, Q2:  What is the big-Oh family for the above code?  Enter the response in the next cell.

# %% [markdown]
# > O(n)

# %% [markdown]
# ===================================================================================================
# ### Problem 6:  View the code in the cell below then answer the questions in the cells that follow.

# %%
def findDupes (A, B):     # Find all elements common to sequences A and B and return them as a list
    """Return a list of all element common to the sequences (lists) A and B."""
    rlist = [ ]
    for a in A:
        for b in B:
            if a == b:
                rlist.append(a)
    return rlist

# %% [markdown]
# #### P1, Q1: What is the T(n) for the above code based on a static analysis?  Put your response in the next cell.

# %% [markdown]
# > c + cn$^2$ + cn + cn + c

# %% [markdown]
# #### P6, Q2:  What is the big-Oh family for the above code?  Put the response in the next cell.

# %% [markdown]
# > O(n$^2$)

# %% [markdown]
# #### P6, Q3: The code below tests the above function by defining two sequences of size 1000 and 500, respectively, then running the function using them as input.  All elements of the second will be in the first.  The code uses the built-in time function to measure the start and end times.  Run the code below to see the result.  Don't forget to run the cell that has the function definition to put it in your name space.  Also be patient - the answer might take up to a minute to appear.

# %%
from time import time
S1 = [n for n in range(0, 1000)]
S2 = [n for n in range(0, 1000, 2) ]
start = time()
x = findDupes(S1, S2)
print(time() - start, '  # elts: ', len(x))
# Out:
# 0.028029203414916992   # elts:  500

# %% [markdown]
# #### P6, Q4: Cut and paste the above code in the above cell into the next one, modify it to change both the sequence sizes to 10,000 (the second sequence only selected every other element, so will be 5,000), rerun the code and note the results.  Then rerun it multiple times for sequences of 20,000, 30,000, 40,000, and 60,000 and note the results.  Enter the resulting times in the cell below.

# %%
from time import time
S1 = [n for n in range(0, 60000)]
S2 = [n for n in range(0, 60000, 2) ]
start = time()
x = findDupes(S1, S2)
print(time() - start, '  # dup elts: ', len(x))
# Out:
# 85.87182879447937   # dup elts:  30000

# %% [markdown]
# Convert this cell to type 'Code', type in the results where indicated, convert the cell back to Markdown, then 'Run'.
#
# 10,000:  1.95 seconds
#
# 20,000:  9.28 seconds
#
# 30,000:  32.5 seconds
#
# 40,000:  36.19 seconds
#
# 60,000:  85.87 seconds

# %% [markdown]
# #### P6, Q5: Review your results for the various runs above.  Is doubling the input size, say from 10,000 to 20,000 or from 20,000 to 40,000 consistent with the big-Oh prediction?  Enter your response in the cell below.

# %% [markdown]
# > <b>Answer</b>: Yes the time complexity stayed consistent to the big oh prediction. With doubling inputs the time also increased as predicted by O(n$^2$)
